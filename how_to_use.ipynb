# %% [markdown]
# # How to use

# %% [markdown]
# ## Imports

# %%
import json
import requests

from FetchURL.fetch_data import DataFetcher
from Controller.Lita import PlayerInSkill, PlayerDetail, PlayerSkillComment, PlayerReceived, MomentUserList, Skills

# %%
def fetch_data_with_error_handling(data_source: str, prettify_json: bool = False):
    data_fetcher = DataFetcher(data_source)
    try:
        data, status_code = data_fetcher.fetch_data()
        if prettify_json and data and isinstance(data, dict):
            data = json.dumps(data, indent=4)
    except Exception as e:
        print(f"An error occurred: {e}")
        data, status_code = None, None
    return data, status_code

# %% [markdown]
# ## 01. PlayerInSkill
#
# | **Category**       | **Option**                   | **Description**                                |
# |--------------------|------------------------------|------------------------------------------------|
# | **Gender**         | 0                            | Both                                           |
# |                    | 1                            | Male                                           |
# |                    | 2                            | Female                                         |
# | **Skill ID**       | 1                            | Mobile Legends                                 |
# |                    | 20                           | Teman Curhat                                   |
# |                    | 3                            | PUBG                                           |
# |                    | 2                            | Free Fire                                      |
# |                    | 100                          | Ludo King                                      |
# |                    | 139                          | Eggy Party                                     |
# |                    | 90                           | Stumble Guys                                   |
# |                    | 22                           | Magic Chess                                    |
# |                    | 21                           | Valorant                                       |
# |                    | 18                           | COD: Mobile                                    |
# |                    | 69                           | Genshin Impact                                 |
# |                    | 23                           | Sausage Man                                    |
# |                    | 87                           | AoV                                            |
# |                    | 10                           | LOL: Wild Rift                                 |
# |                    | 65                           | Dota 2                                         |
# |                    | 89                           | Point Blank                                    |
# |                    | 60                           | CS2                                            |
# |                    | 102                          | Black Desert Mobile                            |
# |                    | 103                          | Sky: Children of the Light                     |
# |                    | 109                          | Supersus                                       |
# |                    | 113                          | Let's Get Rich                                 |
# |                    | 122                          | Teman Nyanyi                                   |
# |                    | 167                          | Honor of Kings                                 |
# | **Page**           | 1 to end                     | Page numbers                                   |
# | **Level IDs**      | newBie (default = 0)         | 0 = False, 1 = True                            |
# | **Order**          | None                         | No specific order                              |
# |                    | desc                         | Descending (default: latest)                   |
# |                    | asc                          | Ascending (oldest)                             |
# | **Position IDs**   | *In Development*             | List any specific position IDs here            |
# | **Rows**           | 1 to 50                      | Number of rows                                 |
# | **Sort**           | None                         | Recommendation                                 |
# |                    | auditTime                    | Sort by audit time                             |
# |                    | avgStar                      | Sort by average star rating                    |
# |                    | price                        | Sort by price                                  |

# %%
gender      = 2
skillId     = 1
levelIds    = ''
newBie      = 0
order       = 'desc'
positionIds = ''
page        = 1
rows        = 50
sort        = 'auditTime'

player_in_skill = PlayerInSkill(gender, skillId, page, levelIds, newBie, order, positionIds, rows, sort).player_inskill_func()
data, status_code = fetch_data_with_error_handling(player_in_skill, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": {
#         "experimentMatched": false,
#         "hasUselessMsg": false,
#         "batchNo": "0",
#         "page": "0",
#         "rows": [
#             {
#                 "id": "17971344",
#                 "no": "23474005",
#                 "nick": "nissa\u2728",
#                 "avatarUrl": "https://data.lita.game/user/17971344/album/photo_20240810_154338_391_R82393.png?t=1723275818391",
#                 "gender": "2",
#                 "intro": "selamat dtng di profil aku( \u25dc\u2060\u203f\u2060\u25dd )\u2060\u2661\naku online 24/7 ya kak\ud83d\ude0b\naku jga bisa main tank,mage di mobile legends\u2764\ufe0f\u200d\ud83d\udd25\nmau cari tmn mbr kk bisa order aku sesuai kebutuhan kk ya\u00a0\u2060\u02d8\u2060\u00a0\u2060\u00b3\u00a0\u2060\u02d8\u2060\u2764\ufe0f\ntrimakasih\ud83d\udc97",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "bisa main fighter,tank,mage\ud83d\ude0b\nbisa langsung pesan saya\ud83d\ude4c",
#                 "skillPosition": "Tank,Fighter,Mage",
#                 "skillAudioUrl": "https://data.lita.game/user/17971344/skill/audio_1_t1723220570759.mp3?t=1723220570759",
#                 "skillAudioSeconds": "4",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "9",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17971344",
#                     "roomId": "10100453",
#                     "roomName": "\ud835\udc02\ud835\udc0b\ud835\udc00\ud835\udc12\ud835\udc12\ud835\udc18 \u2022 HAI GUYS"
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17975661",
#                 "no": "23407831",
#                 "nick": "Lieta.",
#                 "avatarUrl": "https://data.lita.game/user/17975661/album/photo_20240810_122534_627_R11173.jpg?t=1723263934627",
#                 "gender": "2",
#                 "intro": "Hallo!!! \ud83e\udef6\ud83c\udffb\nIG : @wnlxtaa\nTiktok : @wnlxtaa",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "2",
#                 "skillLevelName": "Mythic",
#                 "skillIntro": "Hallo guys \ud83e\ude77 \nyg cari temen Mabar role mm mage bisa order yaa!! \nyuk have fun bareng di temenin aku\ud83e\ude77",
#                 "skillPosition": "Marksman,Mage,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17975661/skill/audio_1_t1723264164114.mp3?t=1723264164114",
#                 "skillAudioSeconds": "11",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "3",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17975661",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17968867",
#                 "no": "23401863",
#                 "nick": "Ini Dindaa\ud83d\udc93",
#                 "avatarUrl": "https://data.lita.game/user/17968867/album/photo_20240809_212244_592_R10063.jpg?t=1723209764592",
#                 "gender": "2",
#                 "intro": "Bisa lane apa aja asal bukan exp hehe\ud83d\ude4c\ud83c\udffc",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "828",
#                 "skillLevelName": "Mythical Honor",
#                 "skillIntro": "Aku bisa heal tepat waktu dan ga hobi ks klo pke Angelaaa",
#                 "skillPosition": "Marksman,Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17968867/skill/audio_1_t1723205190809.caf?t=1723205190810",
#                 "skillAudioSeconds": "13",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "0",
#                 "skillAvgStar": "0.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17968867",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "6951558",
#                 "no": "9845040",
#                 "nick": "vinagemoy",
#                 "avatarUrl": "https://data.lita.game/user/6951558/album/photo_20240809_190137_165_R41959.png?t=1723201297165",
#                 "gender": "2",
#                 "intro": "favorit game : mobile legend \n",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "DKeWdImdR3iprfvIZYU44A",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "1",
#                 "skillLevelName": "Mythic Glory",
#                 "skillIntro": "saya bisa bermain game mode apapun, yang penting kitafun",
#                 "skillPosition": "Mage",
#                 "skillAudioUrl": "https://data.lita.game/user/6951558/skill/audio_1_t1723114620073.mp3?t=1723114620073",
#                 "skillAudioSeconds": "8",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "0",
#                 "skillAvgStar": "0.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "6951558",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17961660",
#                 "no": "23418949",
#                 "nick": "Ronaa.",
#                 "avatarUrl": "https://data.lita.game/user/17961660/album/photo_20240809_083636_128_R89560.jpg?t=1723163796128",
#                 "gender": "2",
#                 "intro": "hiii aku Ronaa tpi panggil aja mandaa\n\nig: virrgow ",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "828",
#                 "skillLevelName": "Mythical Honor",
#                 "skillIntro": "skill not bad laa jago banget kata ayang \nwr aku 50 an hehe",
#                 "skillPosition": "Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17961660/skill/audio_1_t1723162676120.mp3?t=1723162676120",
#                 "skillAudioSeconds": "4",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "6",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17961660",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17587935",
#                 "no": "23047593",
#                 "nick": "Himekoo",
#                 "avatarUrl": "https://data.lita.game/user/17587935/album/photo_20240809_021213_893_R86202.jpg?t=1723140733893",
#                 "gender": "2",
#                 "intro": "Ayo kita main bareng dan have fun bareng acuu!",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "4",
#                 "skillLevelName": "Epic",
#                 "skillIntro": "Ayo kita main bareng dan have fun bareng akuu!",
#                 "skillPosition": "Mage,Support,Roamer",
#                 "skillAudioUrl": "https://data.lita.game/user/17587935/skill/audio_1_t1723141157032.caf?t=1723141157032",
#                 "skillAudioSeconds": "9",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "1",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17587935",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17954464",
#                 "no": "23461511",
#                 "nick": "Thissraaa",
#                 "avatarUrl": "https://data.lita.game/user/17954464/album/photo_20240808_161402_784_R56090.jpg?t=1723104842784",
#                 "gender": "2",
#                 "intro": "Haiiii!!!\ncalon midlen rrq? hehe><\nMidlane ~ Support ",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "828",
#                 "skillLevelName": "Mythical Honor",
#                 "skillIntro": "HAIIII!!\ncalon midlen rrq nih WKWKW\nHAVE FUN GAISSSS><",
#                 "skillPosition": "Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17954464/skill/audio_1_t1723121673837.mp3?t=1723121673837",
#                 "skillAudioSeconds": "5",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "0",
#                 "skillAvgStar": "0.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17954464",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17954605",
#                 "no": "23435264",
#                 "nick": "Nayaw pretty ",
#                 "avatarUrl": "https://data.lita.game/user/17954605/album/photo_20240811_015045_510_R64001.jpg?t=1723312245510",
#                 "gender": "2",
#                 "intro": "hallo aku suka main mobile legend kalo kamu butuh support atau midlaner yang suara nya bikin nyaman dan bisa main dalam mode apapun boleh order aku ya",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "2",
#                 "skillLevelName": "Mythic",
#                 "skillIntro": "Aku bisa ngisi mid sama roam bisa juga jadi support sistem kamu, suara aku bisa bikin kamu nyaman loh\ud83e\udde1",
#                 "skillPosition": "Mage,Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17954605/skill/audio_1_t1723121160337.mp3?t=1723121160337",
#                 "skillAudioSeconds": "12",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "8",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17954605",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17957303",
#                 "no": "23307880",
#                 "nick": "sassysissy",
#                 "avatarUrl": "https://data.lita.game/user/17957303/album/photo_20240808_200820_962_R49671.jpg?t=1723118900962",
#                 "gender": "2",
#                 "intro": "user all role, tp kalau jungler insya Allah\ud83d\ude4f\ud83c\udffb",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "ayo mabar, buat have fun, push rank, mau sambil curhat jg boleh bgt donggg",
#                 "skillPosition": "Support,Midlaner,Roamer",
#                 "skillAudioUrl": "https://data.lita.game/user/17957303/skill/audio_1_t1723119508858.caf?t=1723119508858",
#                 "skillAudioSeconds": "12",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "0",
#                 "skillAvgStar": "0.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17957303",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17954680",
#                 "no": "23458523",
#                 "nick": "na-biiii",
#                 "avatarUrl": "https://data.lita.game/user/17954680/album/photo_20240808_184638_124_R12859.png?t=1723113998124",
#                 "gender": "2",
#                 "intro": "ayooooo mabar ga sih sm aku\ud83d\ude21\ud83e\udef5\ud83c\udffd\u2194\ufe0f",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "828",
#                 "skillLevelName": "Mythical Honor",
#                 "skillIntro": "mabar have fun gas\ud83e\udd29",
#                 "skillPosition": "Marksman,Mage,Support",
#                 "skillAudioUrl": "https://data.lita.game/user/17954680/skill/audio_1_t1723105810350.caf?t=1723105810350",
#                 "skillAudioSeconds": "4",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "2",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17954680",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17943728",
#                 "no": "23381152",
#                 "nick": "Fumiyaa",
#                 "avatarUrl": "https://data.lita.game/user/17943728/album/photo_20240807_164620_913_R50457.jpg?t=1723020380913",
#                 "gender": "2",
#                 "intro": "Emeler alhamdulillah all role exp agak kurang \ud83d\uddff",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "1",
#                 "skillLevelName": "Mythic Glory",
#                 "skillIntro": "Emeler all role excepted exp",
#                 "skillPosition": "Marksman,Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17943728/skill/audio_1_t1723020675294.caf?t=1723020675295",
#                 "skillAudioSeconds": "4",
#                 "skillPrice": "120.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "4",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17943728",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17947384",
#                 "no": "23472470",
#                 "nick": "--Nairaa",
#                 "avatarUrl": "https://data.lita.game/user/17947384/album/photo_20240807_224616_370_R81995.jpg?t=1723041976370",
#                 "gender": "2",
#                 "intro": "Hii , Need support?",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "1",
#                 "skillLevelName": "Mythic Glory",
#                 "skillIntro": "hallo, need support ke aku yaa\nsaya bisa bermain mode apapun serius fun pun bisa",
#                 "skillPosition": "Mage,Support",
#                 "skillAudioUrl": "https://data.lita.game/user/17947384/skill/audio_1_t1723042205896.mp3?t=1723042205897",
#                 "skillAudioSeconds": "15",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "9",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17947384",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17925915",
#                 "no": "23304625",
#                 "nick": "\u0299\u026a\u1d00\u0274\u1d04\u1d00\u1d00\u1d00",
#                 "avatarUrl": "https://data.lita.game/user/17925915/album/photo_20240807_221555_287_R85996.jpg?t=1723040155287",
#                 "gender": "2",
#                 "intro": "Hello, Bianca is here (\u3065\uffe3 \u00b3\uffe3)\u3065\nAku bisa jadi mage dan support sistem kamu \u1566( \u0361\u00b0 \u035c\u0296 \u0361\u00b0)\u1564 \nMau mode serius ayoo mau having fun juga oke \u2728\nkalo mau di seriusin juga boleh hihi ( *\u00af \u00b3\u00af*)\u2661",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "2",
#                 "skillLevelName": "Mythic",
#                 "skillIntro": "aku bisa jadi support dan roamer yang peka banget, aku juga sering menguasai mid line. aku masih bisa menyesuaikan dan melindungi kamu dan kita rebut victory kita bersama ",
#                 "skillPosition": "Mage,Support,Roamer",
#                 "skillAudioUrl": "https://data.lita.game/user/17925915/skill/audio_1_t1722961426597.mp3?t=1722961426597",
#                 "skillAudioSeconds": "15",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "6",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17925915",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17953740",
#                 "no": "23403802",
#                 "nick": "Zhoana\ud83c\udf38",
#                 "avatarUrl": "https://data.lita.game/user/17953740/album/photo_20240811_172159_860_R71690.jpg?t=1723368119860",
#                 "gender": "2",
#                 "intro": "Hallo",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "Hallo kak nama aku zhoana , aku bisa bnget gendong kmu dengan mudah loh sambil bermain have fun",
#                 "skillPosition": "Tank,Mage,Support",
#                 "skillAudioUrl": "https://data.lita.game/user/17953740/skill/audio_1_t1723101334152.caf?t=1723101334152",
#                 "skillAudioSeconds": "8",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "12",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17953740",
#                     "roomId": "10100535",
#                     "roomName": "\ud835\udc11\ud835\udc28\ud835\udc2e\ud835\udc27\ud835\udc1d \ud835\udc13\ud835\udc1a\ud835\udc1b\ud835\udc25\ud835\udc1e || SUNDAY WITH US \ud83d\udc95"
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "11499391",
#                 "no": "14710969",
#                 "nick": "AMEL11A911",
#                 "avatarUrl": "https://data.lita.game/user/11499391/album/photo_20240808_130152_640_R46873.jpg?t=1723093312640",
#                 "gender": "2",
#                 "intro": "order dua free 1 match sama aku yuk have fun atau serius aku bisa support kamu \ud83d\udc96\ud83e\udef6\ud83c\udffb",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "8aekgePORcCKn2FhAD8RuA",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "2",
#                 "skillLevelName": "Mythic",
#                 "skillIntro": "order dua aku kasih free 1 match yuk langsung aja ",
#                 "skillPosition": "Mage,Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/11499391/skill/audio_1_t1723183879957.caf?t=1723183879958",
#                 "skillAudioSeconds": "7",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "11",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "11499391",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17938185",
#                 "no": "23383302",
#                 "nick": "rossielle'a",
#                 "avatarUrl": "https://data.lita.game/user/17938185/album/photo_20240807_032543_320_R27370.jpg?t=1722972343320",
#                 "gender": "2",
#                 "intro": "online=order><\nex Angela, Novaria,Nana, Vexana, Xavier, Carmila, Zhask \n",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "Saya dengan mudah membantumu untuk menang! \njika kamu btuh seseorang untuk suport dan mendapat banyak kil saya orgnya\nsaya cewe manis dan cntik\nsaya bermain game mode apapun, yang penting kita fun",
#                 "skillPosition": "Mage,Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/17938185/skill/audio_1_t1723045309848.mp3?t=1723045309848",
#                 "skillAudioSeconds": "6",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "0",
#                 "skillAvgStar": "0.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17938185",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "16142265",
#                 "no": "21463090",
#                 "nick": "deyychan",
#                 "avatarUrl": "https://data.lita.game/user/16142265/album/photo_20240807_222111_393_R39104.png?t=1723040471393",
#                 "gender": "2",
#                 "intro": "tiktok @kanjengratulivy\norder mbr vip dm",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "hi guys main sm aku yu,, aku bisa supp dengan baik loh sambil kita ngobrol bareng yu aku bisa isi lane mid roam or exp oh ya jangan lupa di order ia guyss namaku deyya 19th ilyyy allll><  wr cl ku 70 ",
#                 "skillPosition": "Mage,Support,Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/16142265/skill/audio_1_t1722920165439.mp3?t=1722920165439",
#                 "skillAudioSeconds": "6",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "14",
#                 "skillAvgStar": "4.69",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "16142265",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "11777473",
#                 "no": "15020719",
#                 "nick": "silviaa_ror",
#                 "avatarUrl": "https://data.lita.game/user/11777473/album/photo_20240807_215720_497_R42674.jpg?t=1723039040497",
#                 "gender": "2",
#                 "intro": "haii, aku suka bermain ml\ud83d\ude17\ud83d\ude17\naku juga suka basket!!!\naku sering on di malam hari yaa",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "IRL4WR4hQy6Y9sqXglwyOQ",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
# ...
#                 "avatarUrl": "https://data.lita.game/user/17884775/album/photo_20240810_124937_266_R42212.jpg?t=1723265377266",
#                 "gender": "2",
#                 "intro": "haiii aku bisa menemani kalian Mabar, Ayok have fun bareng aku gyuss \ud83d\ude19\ud83d\ude0d\ud83e\udd70",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "aku bisa jadi support sistem untukmu !!, Gaskeun Kak siapa tau cocok \ud83d\ude19\ud83e\udd1f\n",
#                 "skillPosition": "Marksman,Mage,Support",
#                 "skillAudioUrl": "https://data.lita.game/user/17884775/skill/audio_1_t1722619540337.mp3?t=1722619540337",
#                 "skillAudioSeconds": "13",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "26",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17884775",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "5817063",
#                 "no": "7656297",
#                 "nick": "aichaa \u029a\u025e",
#                 "avatarUrl": "https://data.lita.game/user/5817063/album/photo_20240802_212347_537_R81166.jpg?t=1722605027537",
#                 "gender": "2",
#                 "intro": "alo aku ica, tak kenal maka tak sayang\ud83d\udc8b",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "GNYJLQKQSiGzk4khssDAiQ",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "828",
#                 "skillLevelName": "Mythical Honor",
#                 "skillIntro": "allo mabar sama aku yuk, siap jdi support kamuuuu\ud83d\udc23",
#                 "skillPosition": "Marksman,Mage,Support",
#                 "skillAudioUrl": "https://data.lita.game/user/5817063/skill/audio_1_t1722606606945.mp3?t=1722606606946",
#                 "skillAudioSeconds": "11",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "13",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "5817063",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "17849139",
#                 "no": "23207646",
#                 "nick": "Ladysun\ud83d\udc00",
#                 "avatarUrl": "https://data.lita.game/user/17849139/album/photo_20240809_112451_003_R91757.jpg?t=1723173891003",
#                 "gender": "2",
#                 "intro": "sini aku gendong",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "0",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "2",
#                 "skillLevelName": "Mythic",
#                 "skillIntro": "mage rasa tank nih brodie wkwk",
#                 "skillPosition": "Marksman,Mage",
#                 "skillAudioUrl": "https://data.lita.game/user/17849139/skill/audio_1_t1722586032378.mp3?t=1722586032378",
#                 "skillAudioSeconds": "9",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "2",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "17849139",
#                     "roomId": "0",
#                     "roomName": ""
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "14290482",
#                 "no": "17631478",
#                 "nick": "\ua02f\u2022 sugarpumpkin",
#                 "avatarUrl": "https://data.lita.game/user/14290482/album/photo_20240809_154318_675_R84916.jpg?t=1723189398675",
#                 "gender": "2",
#                 "intro": "yuk mabar!!! bisa asik bisa serius \ud83d\ude09",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "1",
#                 "skillLevelName": "Mythic Glory",
#                 "skillIntro": "ayooo main sm ak!!! ak jago lho!!!\ud83d\ude12\ud83e\udd72",
#                 "skillPosition": "All Role",
#                 "skillAudioUrl": "https://data.lita.game/user/14290482/skill/audio_1_t1722579222704.caf?t=1722579222704",
#                 "skillAudioSeconds": "5",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "23",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "14290482",
#                     "roomId": "10100561",
#                     "roomName": "\ua02f\u2022 \u1d04\u026a\u0280\u1d04\u029f\u1d07 -  Host baru canciii\ud83e\udeb7"
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "1800358",
#                 "no": "3093861",
#                 "nick": "chlsea \u2764\ufe0f\u200d\ud83d\udd25",
#                 "avatarUrl": "https://data.lita.game/user/1800358/album/photo_20240802_140641_278_R83113.png?t=1722578801278",
#                 "gender": "2",
#                 "intro": "haii lagi butuh temen mabar? ayo main bareng sama akuu",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "zHR49uomSv-yZAKgCmA1Hg",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "aku bisa main support yang siap bantu kamu di saat kamu butuh!",
#                 "skillPosition": "Marksman,Mage,Support",
#                 "skillAudioUrl": "https://data.lita.game/user/1800358/skill/audio_1_t1722431934683.caf?t=1722431934683",
#                 "skillAudioSeconds": "5",
#                 "skillPrice": "120.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "25",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "1800358",
#                     "roomId": "1695",
#                     "roomName": "Hello - Happyweekend\ud83d\udc96"
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             },
#             {
#                 "id": "13109629",
#                 "no": "16311353",
#                 "nick": "Stella Water \ud83e\udea3",
#                 "avatarUrl": "https://data.lita.game/user/13109629/album/photo_20240702_152428_003_R96629.jpg?t=1719905068003",
#                 "gender": "2",
#                 "intro": "Selamat Datang Di Kenyamanan Tanpa Batas Bersama Stella \ud83e\udee6",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "playerQuality": "1",
#                 "isActive": true,
#                 "deleted": false,
#                 "imUid": "",
#                 "birthdayString": "",
#                 "onlineReminder": false,
#                 "kolChatStatus": "disabled",
#                 "isWool": false,
#                 "hasLwDiscount": false,
#                 "skillId": "1",
#                 "skillName": "Mobile Legends",
#                 "skillBrickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "skillBrickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "skillBrickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "skillPcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "skillPcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "skillMiniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "skillLevelId": "3",
#                 "skillLevelName": "Legend",
#                 "skillIntro": "Aku cuma  bisa main nana \ud83d\ude35",
#                 "skillPosition": "Midlaner",
#                 "skillAudioUrl": "https://data.lita.game/user/13109629/skill/audio_1_t1722586607780.mp3?t=1722586607780",
#                 "skillAudioSeconds": "10",
#                 "skillPrice": "100.00",
#                 "skillPriceName": "Match",
#                 "skillOrderCount": "8",
#                 "skillAvgStar": "5.00",
#                 "skillTags": "",
#                 "skillType": "1",
#                 "skillLevelImages": [],
#                 "onlineInfo": {
#                     "userId": "13109629",
#                     "roomId": "10100477",
#                     "roomName": " \u2695 \u029c\ua731\u1d22 |  Happy sunday \u2728"
#                 },
#                 "thirdMedias": [],
#                 "preferredSkills": [],
#                 "levelAuth": false,
#                 "guaranteedWin": false,
#                 "show": true,
#                 "isPhone": true,
#                 "skillTagList": []
#             }
#         ]
#     }
# } 200

# %% [markdown]
# ## 02. PlayerDetail

# %%
no = 23441692

player_detail = PlayerDetail(no).player_detail_func()
data, status_code = fetch_data_with_error_handling(player_detail, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": {
#         "user": {
#             "id": "17976481",
#             "no": "23441692",
#             "nick": "My SASA",
#             "avatarId": "12293668",
#             "avatarUrl": "https://data.lita.game/user/17976481/album/photo_20240810_215841_169_R57692.jpg?t=1723298321169",
#             "gender": "2",
#             "birthday": "1060963200000",
#             "intro": "Hi \nit\u2019s me Sasa\n\ud83d\udccdWest Borneo\n21th",
#             "audioUrl": "https://data.lita.game/user/17976481/profile/audio_1723277835687.caf?t=1723277835687",
#             "audioSeconds": "8",
#             "verifyType": "0",
#             "verifyDescrib": "",
#             "verifyIcon": "",
#             "isPlayer": true,
#             "becomePlayerTime": "1723275397000",
#             "isActive": true,
#             "autoGreetEnabled": false,
#             "autoGreetMsg": "",
#             "vipLevel": "0",
#             "boxId": "0",
#             "age": "21",
#             "birthdayString": "2003-08-16",
#             "imUid": "",
#             "appPlat": "IOS",
#             "appVersion": "1.189",
#             "status": "0",
#             "countryOrRegionCode": "ID",
#             "countryOrRegionName": "Indonesia",
#             "svipLevel": "0",
#             "svipEndTime": "0",
#             "isWool": false,
#             "deleted": false
#         },
#         "blocking": false,
#         "blocked": false,
#         "following": false,
#         "followed": false,
#         "onlineReminder": false,
#         "followCount": "6",
#         "followerCount": "5",
#         "kolChatStatus": "disabled",
#         "room": {
#             "userId": "17976481",
#             "roomId": "0",
#             "roomName": ""
#         },
#         "guild": {
#             "guildMember": false
#         },
#         "album": [
#             {
#                 "id": "12293668",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_215841_169_R57692.jpg?t=1723298321169"
#             },
#             {
#                 "id": "12294081",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_133908_508_R53673.jpg?t=1723268348508"
#             },
#             {
#                 "id": "12294086",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_133930_301_R61021.jpg?t=1723268370301"
#             },
#             {
#                 "id": "12294088",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_133939_898_R92603.jpg?t=1723268379898"
#             },
#             {
#                 "id": "12294101",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_134020_863_R75509.jpg?t=1723268420863"
#             },
#             {
#                 "id": "12294129",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_134305_922_R94344.jpg?t=1723268585922"
#             },
#             {
#                 "id": "12294140",
#                 "url": "https://data.lita.game/user/17976481/album/photo_20240810_134353_575_R93390.jpg?t=1723268633575"
#             }
#         ],
#         "skills": [
#             {
#                 "skillId": "1",
#                 "unit": "1",
#                 "priceName": "Match",
#                 "price": "100.00",
#                 "orderCount": "2",
#                 "avgStar": "5.00",
#                 "intro": "best roamer",
#                 "position": "Mage,Support,Roamer",
#                 "audioUrl": "https://data.lita.game/user/17976481/skill/audio_1_t1723267127917.caf?t=1723267127917",
#                 "audioSeconds": "5",
#                 "levelName": "Mythic",
#                 "levelImage": "",
#                 "levelImages": [
#                     {
#                         "id": "1",
#                         "title": "",
#                         "desc": "Upload Screenshot of \"Profil\" page",
#                         "url": "https://data.lita.game/mgr/skill/202401031906/in_mlbb_level-eg.jpeg?width=3237&height=1875",
#                         "required": true,
#                         "displayOrder": "0",
#                         "imageUrl": "https://data.lita.game/user/17976481/skill/level_1_t1723267121902.jpg?t=1723267121923&width=1473&height=828"
#                     }
#                 ],
#                 "commentNumWithContent": "2",
#                 "status": "0",
#                 "auditTime": "1723275397000",
#                 "levelAuth": false,
#                 "id": "1",
#                 "name": "Mobile Legends",
#                 "brickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#                 "brickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#                 "brickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#                 "imageUrl": "https://data.lita.game/static/skill/square/sq_mlbb.png",
#                 "mainIconUrl": "https://data.lita.game/static/skill/home_icon/new_mlbb_home_icon.png",
#                 "miniIconUrl": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png",
#                 "iconUrl": "https://data.lita.game/static/skill/square/sq_mlbb.png",
#                 "pcIconUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-icon.jpeg?width=253&height=320",
#                 "pcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#                 "type": "1",
#                 "allowLuckyWheel": true,
#                 "promoRequiredCount": "0",
#                 "promoCount": "0",
#                 "commentTags": [
#                     {
#                         "name": "Lucu dan menghibur",
#                         "num": "1"
#                     },
#                     {
#                         "name": "Mengendong tim",
#                         "num": "1"
#                     },
#                     {
#                         "name": "Asik",
#                         "num": "1"
#                     },
#                     {
#                         "name": "Sabar dan sopan",
#                         "num": "1"
#                     },
#                     {
#                         "name": "Suara manis",
#                         "num": "1"
#                     },
#                     {
#                         "name": "Kerja sama tim",
#                         "num": "1"
#                     }
#                 ],
#                 "sortingPoints": "0.0",
#                 "fx": "0.0",
#                 "fx1": "0.0",
#                 "skillLevelKey": "Rank/Tier Game",
#                 "skillPositionKey": "Posisi terbaik"
#             }
#         ],
#         "thirdMedias": [],
#         "supporterTop": [
#             {
#                 "id": "3967687",
#                 "no": "5553326",
#                 "nick": "Lita1169061196",
#                 "avatarUrl": "https://data.lita.game/user/3967687/album/photo_20240704_040511_281_R15761.jpg?t=1720037111281"
#             },
#             {
#                 "id": "9885427",
#                 "no": "13018699",
#                 "nick": "Titik koma. ",
#                 "avatarUrl": "https://data.lita.game/user/9885427/album/photo_20240722_114134_071_R64573.jpg?t=1721619694071"
#             }
#         ],
#         "giftCollection": [
#             {
#                 "giftName": "Cutie Paw",
#                 "giftIco": "https://data.lita.game/mgr/gift/1803/20240507174322.png?width=350&height=350",
#                 "giftImg": "https://data.lita.game/mgr/gift/1803/20240507174322.png?width=350&height=350",
#                 "totalCount": "1",
#                 "top1UserId": "3967687",
#                 "groupKey": "class:0",
#                 "groupType": "giftClass",
#                 "lastGiftId": "7884",
#                 "giftClassId": "1803",
#                 "giftStairs": "0"
#             },
#             {
#                 "giftName": "Cutie Kitty",
#                 "giftIco": "https://data.lita.game/mgr/gift/1802/20240507174116.png?width=350&height=350",
#                 "giftImg": "https://data.lita.game/mgr/gift/1802/20240507174116.png?width=350&height=350",
#                 "totalCount": "1",
#                 "top1UserId": "3967687",
#                 "groupKey": "class:0",
#                 "groupType": "giftClass",
#                 "lastGiftId": "7886",
#                 "giftClassId": "1802",
#                 "giftStairs": "0"
#             }
#         ],
#         "showRank": true,
#         "giftClassCount": "2",
#         "supporterRankUrl": "https://h5.lita.game/personal-list?fullScreen=true",
#         "giftCollectionUrl": "https://h5.lita.game/gift-wall?fullScreen=true",
#         "nobleInfo": {
#             "nobleLevel": "0",
#             "nobleType": "",
#             "expireTime": "0"
#         },
#         "nameplateInfo": {
#             "nameplates": []
#         },
#         "giftWall": {
#             "giftWallH5UrlHalf": "https://h5.lita.game/gift-wall/v2?pop_bg=transparent&pop_width=750&pop_height=1236",
#             "giftWallH5UrlFull": "https://h5.lita.game/gift-wall/v2?fullScreen=true"
#         },
#         "hasLwDiscount": true,
#         "isPhone": true,
#         "sourceName": "MST",
#         "isNewFriend": false
#     }
# } 200

# %% [markdown]
# ## 03. PlayerSkillComment

# %%
skillId = 1
id      = 2190186
page    = 1

player_skill_comment = PlayerSkillComment(skillId, id, page).player_skill_comment_func()
data, status_code = fetch_data_with_error_handling(player_skill_comment, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": {
#         "total": "2434",
#         "rows": [
#             {
#                 "id": "10150102",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1723234181000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10120306",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap tim",
#                 "anonymous": true,
#                 "createTime": "1722971833000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10120148",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice..",
#                 "anonymous": true,
#                 "createTime": "1722970567000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10089851",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice..",
#                 "anonymous": true,
#                 "createTime": "1722718749000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10089497",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1722715073000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10089040",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice..",
#                 "anonymous": true,
#                 "createTime": "1722712347000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10088399",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1722708691000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10082044",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1722669275000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10078782",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1722629671000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10078323",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1722625641000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10077778",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1722622103000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10076972",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "keren..",
#                 "anonymous": true,
#                 "createTime": "1722617843000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10018490",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap n keren..",
#                 "anonymous": true,
#                 "createTime": "1722108726000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "10017452",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1722102552000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9970823",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "Pro sangat..",
#                 "anonymous": true,
#                 "createTime": "1721669847000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9970300",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1721667167000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9962371",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1721586351000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9962138",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "kerenn",
#                 "anonymous": true,
#                 "createTime": "1721584801000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9961820",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "kereeennn",
#                 "anonymous": true,
#                 "createTime": "1721582462000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9961192",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1721578870000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9960129",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap sangat",
#                 "anonymous": true,
#                 "createTime": "1721574161000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9959315",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1721569805000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9958653",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1721565858000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9957592",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1721556453000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9957002",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1721551793000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9955574",
#                 "userId": "17705218",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mksh kk",
#                 "anonymous": true,
#                 "createTime": "1721536666000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "101",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9953959",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice..",
#                 "anonymous": true,
#                 "createTime": "1721509597000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9953716",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1721506089000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9952870",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1721499263000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9951970",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "mantap",
#                 "anonymous": true,
#                 "createTime": "1721494069000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9945204",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "niceeee",
#                 "anonymous": true,
#                 "createTime": "1721422222000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9945051",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1721419617000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9944587",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "nice",
#                 "anonymous": true,
#                 "createTime": "1721415071000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9944046",
#                 "userId": "13302091",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "keren sangat",
#                 "anonymous": true,
#                 "createTime": "1721411170000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9908704",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1721092605000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9908444",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1721087518000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9907662",
#                 "userId": "4870236",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg \ud83d\udc4d\ud83c\udffb",
#                 "anonymous": false,
#                 "createTime": "1721072238000",
#                 "appealStatus": "0",
#                 "userNick": "Psyco\u2122",
#                 "userAvatarUrl": "https://data.lita.game/user/4870236/album/photo_20240731_004347_145_R52893.jpg?t=1722357827145",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1727715600000"
#             },
#             {
#                 "id": "9907474",
#                 "userId": "4870236",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg \ud83d\udc4d\ud83c\udffb",
#                 "anonymous": false,
#                 "createTime": "1721070499000",
#                 "appealStatus": "0",
#                 "userNick": "Psyco\u2122",
#                 "userAvatarUrl": "https://data.lita.game/user/4870236/album/photo_20240731_004347_145_R52893.jpg?t=1722357827145",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "401",
#                 "userBoxId": "0",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1727715600000"
#             },
#             {
#                 "id": "9895804",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1720965861000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9895110",
#                 "userId": "537392",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG",
#                 "anonymous": false,
#                 "createTime": "1720962973000",
#                 "appealStatus": "0",
#                 "userNick": "David Jun",
#                 "userAvatarUrl": "https://data.lita.cool/user/537392/album/photo_20220623_155753_504_R39838.jpg?t=1655971073504",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "408",
#                 "userBoxId": "2",
#                 "userSvipLevel": "1002",
#                 "userSvipEndTime": "1725123600000"
#             },
#             {
#                 "id": "9578067",
#                 "userId": "11038421",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg",
#                 "anonymous": false,
#                 "createTime": "1718110209000",
#                 "appealStatus": "0",
#                 "userNick": ".,_",
#                 "userAvatarUrl": "https://data.lita.cool/user/11038421/album/photo_20230620_183746_950_R20342.jpg?t=1687257466951",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "303",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9578063",
#                 "userId": "11038421",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg",
#                 "anonymous": false,
#                 "createTime": "1718110189000",
#                 "appealStatus": "0",
#                 "userNick": ".,_",
#                 "userAvatarUrl": "https://data.lita.cool/user/11038421/album/photo_20230620_183746_950_R20342.jpg?t=1687257466951",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "303",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9578060",
#                 "userId": "11038421",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg",
#                 "anonymous": false,
#                 "createTime": "1718110166000",
#                 "appealStatus": "0",
#                 "userNick": ".,_",
#                 "userAvatarUrl": "https://data.lita.cool/user/11038421/album/photo_20230620_183746_950_R20342.jpg?t=1687257466951",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "303",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9578054",
#                 "userId": "7785265",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg",
#                 "anonymous": false,
#                 "createTime": "1718110098000",
#                 "appealStatus": "0",
#                 "userNick": "Lita7785265",
#                 "userAvatarUrl": "https://data.lita.cool/static/avatar/avatar_1.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "301",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9578049",
#                 "userId": "7785265",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg",
#                 "anonymous": false,
#                 "createTime": "1718110077000",
#                 "appealStatus": "0",
#                 "userNick": "Lita7785265",
#                 "userAvatarUrl": "https://data.lita.cool/static/avatar/avatar_1.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "301",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9578044",
#                 "userId": "7785265",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "gg kak",
#                 "anonymous": false,
#                 "createTime": "1718110056000",
#                 "appealStatus": "0",
#                 "userNick": "Lita7785265",
#                 "userAvatarUrl": "https://data.lita.cool/static/avatar/avatar_1.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "301",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9544837",
#                 "userId": "16975331",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "GG kak",
#                 "anonymous": false,
#                 "createTime": "1717824561000",
#                 "appealStatus": "0",
#                 "userNick": "Lita16975331",
#                 "userAvatarUrl": "https://data.lita.cool/static/avatar/avatar_4.jpeg",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "101",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9532678",
#                 "userId": "16950387",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "keren",
#                 "anonymous": true,
#                 "createTime": "1717716604000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "101",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9420509",
#                 "userId": "15120174",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "ka nana",
#                 "anonymous": true,
#                 "createTime": "1716800361000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "103",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             },
#             {
#                 "id": "9420508",
#                 "userId": "15120174",
#                 "targetUserId": "2190186",
#                 "targetSkillId": "1",
#                 "star": "5",
#                 "content": "ka nana",
#                 "anonymous": true,
#                 "createTime": "1716800354000",
#                 "appealStatus": "0",
#                 "userNick": "Anonymous Review",
#                 "userAvatarUrl": "https://data.lita.game/static/avatar/anonymous.png",
#                 "userVerifyType": "0",
#                 "userVerifyDescrib": "",
#                 "userVerifyIcon": "",
#                 "userVipLevel": "103",
#                 "userBoxId": "0",
#                 "userSvipLevel": "0",
#                 "userSvipEndTime": "0"
#             }
#         ]
#     }
# } 200

# %% [markdown]
# ## 04. PlayerReceived

# %% [markdown]
# ### Player Received Gift

# %%
id = 2190186

player_received_gift = PlayerReceived(id).player_received_gift_func()
data, status_code = fetch_data_with_error_handling(player_received_gift, prettify_json=True)
print(data, status_code)
# Out:
# An error occurred: HTTPSConnectionPool(host='api.funbit.me', port=443): Max retries exceeded with url: /funbit/v2/player/received/gift?id=2190186 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000277011AD4F0>: Failed to resolve 'api.funbit.me' ([Errno 11001] getaddrinfo failed)"))
# An error occurred: cannot access local variable 'response' where it is not associated with a value
# None None

# %% [markdown]
# ### Player Received Rank Total

# %%
id = 2190186

player_received_rank_total = PlayerReceived(id).player_received_rank_total_func()
data, status_code = fetch_data_with_error_handling(player_received_rank_total, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": [
#         {
#             "id": "13302091",
#             "no": "7197800",
#             "nick": "3121CK_DJB",
#             "avatarUrl": "https://data.lita.cool/user/13302091/album/photo_20231127_051234_000_R75057.jpg?t=1701033154000",
#             "costCoin": "5280",
#             "vipLevel": "401",
#             "boxId": "0"
#         }
#     ]
# } 200

# %% [markdown]
# ### Player Received Rank Gift

# %%
id = 2190186

player_received_rank_gift = PlayerReceived(id).player_received_rank_gift_func()
data, status_code = fetch_data_with_error_handling(player_received_rank_gift, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": []
# } 200

# %% [markdown]
# ### Player Received Rank Order

# %% [markdown]
# ## 05. MomentUserList

# %%
id = 2190186

moment_user_list = MomentUserList(id).moment_user_list_func()
data, status_code = fetch_data_with_error_handling(moment_user_list, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": {
#         "datas": [
#             {
#                 "momentId": "170356866700001",
#                 "authorId": "2190186",
#                 "momentType": "images",
#                 "createTime": "1703568667000",
#                 "content": {
#                     "text": {
#                         "text": "ingpo link gacor\ud83e\udd1f\ud83d\ude0e",
#                         "ats": []
#                     },
#                     "images": {
#                         "pics": [
#                             {
#                                 "path": "file/moment/images/20231226/2190186/96697464491157109835845588048330_2190186_0.jpg",
#                                 "url": "https://data.lita.cool/file/moment/images/20231226/2190186/96697464491157109835845588048330_2190186_0.jpg",
#                                 "width": "995",
#                                 "height": "1500"
#                             }
#                         ]
#                     },
#                     "skill": {
#                         "skillId": "1",
#                         "skillName": "Mobile Legends",
#                         "price": "120.00",
#                         "priceName": "Match",
#                         "skillPic": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png"
#                     }
#                 },
#                 "grade": "-1",
#                 "showMode": "all",
#                 "no": "3582871",
#                 "nickname": "BANANAAA\ud83d\udc23",
#                 "avatarUrl": "https://data.lita.game/user/2190186/album/photo_20240805_005303_490_R18033.jpg?t=1722790383490",
#                 "commentCount": "0",
#                 "praiseCount": "25",
#                 "praiseState": false,
#                 "isPlayer": true,
#                 "isActive": false,
#                 "follow": false,
#                 "vipLevel": "301",
#                 "boxId": "1",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "verifyIcon": ""
#             },
#             {
#                 "momentId": "169015769000001",
#                 "authorId": "2190186",
#                 "momentType": "video",
#                 "createTime": "1690157690000",
#                 "content": {
#                     "text": {
#                         "text": "DASAR AKUU",
#                         "ats": []
#                     },
#                     "video": {
#                         "path": "file/moment/video/20230724/2190186/40013579020833122489468785717600_2190186_0.mp4",
#                         "coverPath": "file/moment/video/20230724/2190186/40013579020833122489468785717600_2190186_0.jpg",
#                         "url": "https://data.lita.cool/file/moment/video/20230724/2190186/40013579020833122489468785717600_2190186_0.mp4",
#                         "cover": "https://data.lita.cool/file/moment/video/20230724/2190186/40013579020833122489468785717600_2190186_0.jpg",
#                         "width": "1280",
#                         "height": "720",
#                         "time": "15300"
#                     }
#                 },
#                 "grade": "-1",
#                 "showMode": "all",
#                 "no": "3582871",
#                 "nickname": "BANANAAA\ud83d\udc23",
#                 "avatarUrl": "https://data.lita.game/user/2190186/album/photo_20240805_005303_490_R18033.jpg?t=1722790383490",
#                 "commentCount": "3",
#                 "praiseCount": "58",
#                 "praiseState": false,
#                 "isPlayer": true,
#                 "isActive": false,
#                 "follow": false,
#                 "vipLevel": "301",
#                 "boxId": "1",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "verifyIcon": ""
#             },
#             {
#                 "momentId": "169002445300001",
#                 "authorId": "2190186",
#                 "momentType": "images",
#                 "createTime": "1690024453000",
#                 "content": {
#                     "text": {
#                         "text": "lucunyaaa",
#                         "ats": []
#                     },
#                     "images": {
#                         "pics": [
#                             {
#                                 "path": "file/moment/images/20230722/2190186/57131871236321514283585851647202_2190186_0.jpg",
#                                 "url": "https://data.lita.cool/file/moment/images/20230722/2190186/57131871236321514283585851647202_2190186_0.jpg",
#                                 "width": "844",
#                                 "height": "1500"
#                             }
#                         ]
#                     },
#                     "skill": {
#                         "skillId": "1",
#                         "skillName": "Mobile Legends",
#                         "price": "120.00",
#                         "priceName": "Match",
#                         "skillPic": "https://data.lita.game/static/skill/mini_icon/new_mlbb_mini_icon.png"
#                     }
#                 },
#                 "grade": "0",
#                 "showMode": "all",
#                 "no": "3582871",
#                 "nickname": "BANANAAA\ud83d\udc23",
#                 "avatarUrl": "https://data.lita.game/user/2190186/album/photo_20240805_005303_490_R18033.jpg?t=1722790383490",
#                 "commentCount": "13",
#                 "praiseCount": "57",
#                 "praiseState": false,
#                 "isPlayer": true,
#                 "isActive": false,
#                 "follow": false,
#                 "vipLevel": "301",
#                 "boxId": "1",
#                 "verifyType": "0",
#                 "verifyDescrib": "",
#                 "verifyIcon": ""
#             }
#         ],
#         "nextMomentId": "169002445300001"
#     }
# } 200

# %% [markdown]
# ## 06. Skills

# %%
skills = Skills.skills_func()
data, status_code = fetch_data_with_error_handling(skills, prettify_json=True)
print(data, status_code)
# Out:
# {
#     "status": "0",
#     "msg": "",
#     "data": [
#         {
#             "id": "1",
#             "name": "Mobile Legends",
#             "title": "Mobile Legends",
#             "brickIcon": "https://data.lita.game/static/skill/skill_1_brick.png",
#             "brickNewIcon": "https://data.lita.game/mgr/skill/202311301923/in_mlbb_brick-icon.png?width=160&height=160",
#             "brickMini": "https://data.lita.game/static/skill/skill_1_brick_mini.png",
#             "imageUrl": "https://data.lita.game/static/skill/skill_1.png?t=t",
#             "mainIconUrl": "https://data.lita.game/static/skill/home_icon/new_mlbb_home_icon.png",
#             "iconUrl": "https://data.lita.game/static/skill/square/sq_mlbb.png",
#             "pcImageUrl": "https://data.lita.game/mgr/skill/202310081556/in_mobile-legends_pc-image.jpeg?width=253&height=320",
#             "bannerUrl": "https://data.lita.game/static/skill/skill_1_banner.png",
#             "type": "1",
#             "unit": "1"
#         },
#         {
#             "id": "20",
#             "name": "Teman Curhat",
#             "title": "Teman Curhat",
#             "brickIcon": "https://data.lita.game/static/skill/skill_20_brick.png",
#             "brickNewIcon": "https://data.lita.game/mgr/skill/202311301926/in_chat_brick-icon.png?width=160&height=160",
#             "brickMini": "https://data.lita.game/static/skill/skill_20_brick_mini.png",
#             "imageUrl": "https://data.lita.game/static/skill/skill_20_icon.png",
#             "mainIconUrl": "https://data.lita.game/static/skill/home_icon/just_chatting.png",
#             "iconUrl": "https://data.lita.game/static/skill/square/sq_chat.png",
#             "pcImageUrl": "https://data.lita.game/mgr/skill/202310081557/in_chat_pc-image.jpeg?width=253&height=320",
#             "bannerUrl": "https://data.lita.game/static/skill/skill_20_banner.png",
#             "type": "2",
#             "unit": "2"
#         },
#         {
#             "id": "3",
#             "name": "PUBG",
#             "title": "PUBG",
#             "brickIcon": "https://data.lita.game/static/skill/skill_3_brick.png",
#             "brickNewIcon": "https://data.lita.game/mgr/skill/202311301926/in_pubg_brick-icon.png?width=160&height=160",
#             "brickMini": "https://data.lita.game/static/skill/skill_3_brick_mini.png",
#             "imageUrl": "https://data.lita.game/static/skill/skill_3.png?t=t",
#             "mainIconUrl": "https://data.lita.game/static/skill/home_icon/pubg.png",
#             "iconUrl": "https://data.lita.game/static/skill/square/sg_pubg.png",
#             "pcImageUrl": "https://data.lita.game/mgr/skill/202310081558/in_pubg_pc-image.jpeg?width=253&height=320",
#             "bannerUrl": "https://data.lita.game/static/skill/skill_3_banner.png",
#             "type": "1",
#             "unit": "2"
#         },
#         {
#             "id": "2",
#             "name": "Free Fire",
#             "title": "Free Fire",
#             "brickIcon": "https://data.lita.game/static/skill/skill_2_brick.png",
#             "brickNewIcon": "https://data.lita.game/mgr/skill/202311301926/in_ff_brick-icon.png?width=160&height=160",
#             "brickMini": "https://data.lita.game/static/skill/skill_2_brick_mini.png",
#             "imageUrl": "https://data.lita.game/static/skill/skill_2.png?t=t",
#             "mainIconUrl": "https://data.lita.game/static/skill/home_icon/ff.png",
#             "iconUrl": "https://data.lita.game/static/skill/square/sq_ff.png",
#             "pcImageUrl": "https://data.lita.game/mgr/skill/202310081559/in_free-fire_pc-image.jpeg?width=253&height=320",
#             "bannerUrl": "https://data.lita.game/static/skill/skill_2_banner.png",
#             "type": "1",
#             "unit": "2"
#         },
#         {
#             "id": "167",
#             "name": "Honor of Kings",
#             "title": "Honor of Kings",
#             "brickIcon": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_brick-icon.png?width=192&height=192",
#             "brickNewIcon": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_brick-new-icon.png?width=192&height=192",
#             "brickMini": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_brick-mini.png?width=160&height=160",
#             "imageUrl": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_brick-icon.png?width=192&height=192",
#             "mainIconUrl": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_main-icon.png?width=240&height=240",
#             "iconUrl": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_brick-icon.png?width=192&height=192",
#             "pcImageUrl": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_pc-image.png?width=273&height=345",
#             "bannerUrl": "https://data.lita.game/mgr/skill/202406211438/in_honor-of-king_brick-icon.png?width=192&height=192",
#             "type": "1",
#             "unit": "1"
#         },
#         {
#             "id": "100",
#             "name": "Ludo King",
#             "title": "Ludo King",
#             "brickIcon": "https://data.lita.game/mgr/skill/202208231738/20220823174659.png",
#             "brickNewIcon": "https://data.lita.game/mgr/skill/202311301926/in_ludo_brick-icon.png?width=160&height=160",
#             "brickMini": "https://data.lita.game/mgr/skill/202208231738/20220823174729.png",
#             "imageUrl": "https://data.lita.game/mgr/skill/202208231738/20220823174659.png",
#             "mainIconUrl": "https://data.lita.game/mgr/skill/202208231738/20220823174927.png",
#             "iconUrl": "https://data.lita.game/mgr/skill/202208261653/20220826165340.png",
#             "pcImageUrl": "https://data.lita.game/mgr/skill/202310081658/in_ludo-king_pc-image.jpeg?width=253&height=320",
#             "bannerUrl": "https://data.lita.game/mgr/skill/202208231738/20220823174659.png",
#             "type": "1",
#             "unit": "2"
#         }
#     ]
# } 200

# %% [markdown]
# # Next Step

# %% [markdown]
# ## Save to json

# %%
# load the data from url
gender      = 2
skillId     = 1
levelIds    = ''
newBie      = 0
order       = 'desc'
positionIds = ''
page        = 1
rows        = 50
sort        = 'auditTime'

player_in_skill = PlayerInSkill(gender, skillId, page, levelIds, newBie, order, positionIds, rows, sort).player_inskill_func()
data, status_code = fetch_data_with_error_handling(player_in_skill, prettify_json=False)
# print(data)

# save the data to 'json/lita_mlbb/{gender}_{skillId}_{page}.json'
import json
save_path = f'json/lita_mlbb/{gender}_{skillId}_{page}.json'

with open(save_path, 'w') as json_file:
    json.dump(data, json_file, indent=4)

print(f"Data saved to {save_path}")
# Out:
# Data saved to json/lita_mlbb/2_1_1.json

# %%
'''
json data
{
    "status": "0",
    "msg": "",
    "data": {
        "experimentMatched": false,
        "hasUselessMsg": false,
        "batchNo": "0",
        "page": "0",
        "rows": [
            {
                "id": "17976481",
                "no": "23441692",
                "nick": "My SASA",
                "avatarUrl": "https://data.lita.game/user/17976481/album/photo_20240810_215841_169_R57692.jpg?t=1723298321169",
                "gender": "2",
                ...
            },
            {
                "id": "17975661",
                "no": "23407831",
                "nick": "Lieta.",
                "avatarUrl": "https://data.lita.game/user/17975661/album/photo_20240810_122534_627_R11173.jpg?t=1723263934627",
                "gender": "2",
'''

# load the data from 'json/lita_mlbb/{gender}_{skillId}_{page}.json'
load_path = f'json/lita_mlbb/{gender}_{skillId}_{page}.json'

with open(load_path, 'r') as json_file:
    data = json.load(json_file)

print(data['data']['rows'][0]['id'])
print(data['data']['rows'][0]['no'])
print(data['data']['rows'][0]['avatarUrl'])
# Out:
# 17976481
# 23441692
# https://data.lita.game/user/17976481/album/photo_20240810_215841_169_R57692.jpg?t=1723298321169

# %%
load_path = f'json/lita_mlbb/{gender}_{skillId}_{page}.json'

with open(load_path, 'r') as json_file:
    data = json.load(json_file)

print(data['data']['rows'][0]['id'])
print(data['data']['rows'][0]['no'])
print(data['data']['rows'][0]['avatarUrl'])

# loop the data
for row in data['data']['rows']:
    print(row['no'])
    print(row['avatarUrl'])
# Out:
# 17976481
# 23441692
# https://data.lita.game/user/17976481/album/photo_20240810_215841_169_R57692.jpg?t=1723298321169
# 23441692
# https://data.lita.game/user/17976481/album/photo_20240810_215841_169_R57692.jpg?t=1723298321169
# 23407831
# https://data.lita.game/user/17975661/album/photo_20240810_122534_627_R11173.jpg?t=1723263934627
# 23401863
# https://data.lita.game/user/17968867/album/photo_20240809_212244_592_R10063.jpg?t=1723209764592
# 23488697
# https://data.lita.game/user/17965144/album/photo_20240809_165836_908_R30049.jpg?t=1723193916908
# 23328668
# https://data.lita.game/user/17909694/album/photo_20240805_180117_502_R29040.jpg?t=1722852077502
# 23418949
# https://data.lita.game/user/17961660/album/photo_20240809_083636_128_R89560.jpg?t=1723163796128
# 23047593
# https://data.lita.game/user/17587935/album/photo_20240809_021213_893_R86202.jpg?t=1723140733893
# 23461511
# https://data.lita.game/user/17954464/album/photo_20240808_161402_784_R56090.jpg?t=1723104842784
# 23307880
# https://data.lita.game/user/17957303/album/photo_20240808_200820_962_R49671.jpg?t=1723118900962
# 23458523
# https://data.lita.game/user/17954680/album/photo_20240808_184638_124_R12859.png?t=1723113998124
# 23472470
# https://data.lita.game/user/17947384/album/photo_20240807_224616_370_R81995.jpg?t=1723041976370
# 23343842
# https://data.lita.game/user/17892929/album/photo_20240807_181513_161_R49068.png?t=1723025713161
# 23304625
# https://data.lita.game/user/17925915/album/photo_20240807_221555_287_R85996.jpg?t=1723040155287
# 23403802
# https://data.lita.game/user/17953740/album/photo_20240811_172159_860_R71690.jpg?t=1723368119860
# 14710969
# https://data.lita.game/user/11499391/album/photo_20240808_130152_640_R46873.jpg?t=1723093312640
# 23383302
# https://data.lita.game/user/17938185/album/photo_20240807_032543_320_R27370.jpg?t=1722972343320
# 15020719
# https://data.lita.game/user/11777473/album/photo_20240807_215720_497_R42674.jpg?t=1723039040497
# 23169786
# https://data.lita.game/user/17691730/album/photo_20240720_150005_426_R64896.jpg?t=1721458805426
# 22010694
# https://data.lita.game/user/16665339/album/photo_20240806_215551_724_R47378.jpg?t=1722952551724
# 23112362
# https://data.lita.game/user/17734038/album/photo_20240807_102439_484_R38977.jpg?t=1722997479484
# 23218281
# https://data.lita.game/user/17921988/album/photo_20240807_194104_643_R16591.jpg?t=1723030864643
# 23387559
# https://data.lita.game/user/17914144/album/photo_20240807_214946_260_R86749.jpg?t=1723038586260
# 23341615
# https://data.lita.game/user/17934162/album/photo_20240809_190345_377_R16533.jpg?t=1723201425377
# 23385425
# https://data.lita.game/user/17933887/album/photo_20240809_202430_234_R10907.jpg?t=1723206270234
# 23381124
# https://data.lita.game/user/17903291/album/photo_20240808_222120_512_R38780.jpg?t=1723126880512
# 23393219
# https://data.lita.game/user/17915995/album/photo_20240806_164308_049_R67060.png?t=1722933788049
# 23209090
# https://data.lita.game/user/17797925/album/photo_20240727_231926_670_R68884.jpg?t=1722093566670
# 23384522
# https://data.lita.game/user/17918030/album/photo_20240807_143849_525_R57122.jpg?t=1723012729525
# 23367060
# https://data.lita.game/user/17921218/album/photo_20240806_161034_052_R51663.png?t=1722931834052
# 23335698
# https://data.lita.game/user/17929423/album/photo_20240806_122154_712_R61832.jpg?t=1722918114712
# 23221889
# https://data.lita.game/user/17832068/album/photo_20240811_085136_753_R74291.jpg?t=1723337496753
# 23301990
# https://data.lita.game/user/17902323/album/photo_20240804_093448_882_R94515.jpg?t=1722735288882
# 23310114
# https://data.lita.game/user/17918304/album/photo_20240806_171754_535_R36603.jpg?t=1722935874535
# 23009060
# https://data.lita.game/user/17572731/album/photo_20240802_194149_525_R95258.jpg?t=1722598909525
# 23104726
# https://data.lita.game/user/17692596/album/photo_20240802_211241_535_R97537.jpg?t=1722604361535
# 23008649
# https://data.lita.game/user/17584985/album/photo_20240720_081318_651_R83598.jpg?t=1721434398651
# 23008638
# https://data.lita.game/user/17600343/album/photo_20240802_142340_270_R47702.jpg?t=1722579820270
# 12407579
# https://data.lita.game/user/9252572/album/photo_20240803_012840_164_R55227.jpg?t=1722619720164
# 22965756
# https://data.lita.game/user/17540609/album/photo_20240805_153423_923_R40410.jpg?t=1722843263923
# 23104491
# https://data.lita.game/user/17919634/album/photo_20240807_114947_487_R33274.jpg?t=1723002587487
# 21926757
# https://data.lita.cool/user/16562987/album/photo_20240511_154713_951_R21056.jpg?t=1715413633951
# 23190211
# https://data.lita.game/user/17682536/album/photo_20240804_221837_521_R71202.jpg?t=1722781117521
# 23322286
# https://data.lita.game/user/17897319/album/photo_20240803_235157_879_R11217.jpg?t=1722700317879
# 23098637
# https://data.lita.game/user/17565967/album/photo_20240731_164403_680_R13084.jpg?t=1722415443680
# 23312117
# https://data.lita.game/user/17881039/album/photo_20240803_151304_960_R99462.png?t=1722669184960
# 23337594
# https://data.lita.game/user/17891122/album/photo_20240803_142631_745_R49990.jpg?t=1722666391745
# 23339013
# https://data.lita.game/user/17884775/album/photo_20240810_124937_266_R42212.jpg?t=1723265377266
# 7656297
# https://data.lita.game/user/5817063/album/photo_20240802_212347_537_R81166.jpg?t=1722605027537
# 23207646
# https://data.lita.game/user/17849139/album/photo_20240809_112451_003_R91757.jpg?t=1723173891003
# 3093861
# https://data.lita.game/user/1800358/album/photo_20240802_140641_278_R83113.png?t=1722578801278
